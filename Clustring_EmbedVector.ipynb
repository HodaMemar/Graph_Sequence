# %% [markdown]
# # Read All Embedded_Labeled Dataset

# %%
import pandas as pd

# %%
Intracerebral=pd.read_csv("D:\Embedding\Code\Data_Hemorhage\EmbeddedVecor_Intracerebral_Note.csv")

# %%
Subarachnoid=pd.read_csv("D:\Embedding\Code\Data_Hemorhage\EmbeddedVecor_Subarachnoid_Note.csv")

# %%
print(Intracerebral.shape)
print(Subarachnoid.shape)
# Out:
# (636, 24)
# (436, 24)

# %%
Subarachnoid.head()
# Out:
#          f0        f1        f2        f3        f4        f5        f6  \
# 0 -1.993853  2.178629  4.634442 -4.074425 -1.374232 -3.192714 -4.908402
# 1  0.475536  1.927243  3.085145 -0.036732 -3.560901 -4.252589  0.808282
# 2 -2.877875  1.967289  2.633323 -1.234404 -1.239121  3.586148  0.729204
# 3 -1.190131  4.573689  3.632604 -1.645159 -1.493878  0.833972 -4.385071
# 4 -3.431753 -1.453439  4.295153 -1.169358 -1.783434 -6.392317 -0.782893
#
#          f7        f8        f9  ...       f14       f15       f16       f17  \
# 0 -3.232991 -3.999417  2.012876  ... -2.512828  0.570591  0.489019  2.668262
# 1 -0.964753 -2.947562  3.100114  ... -0.304466  5.330497  3.199794 -3.394597
# 2 -0.053369 -3.148829  1.846580  ... -3.508114 -0.570176  3.422779  1.372151
# 3  0.166064 -8.993877  3.556108  ... -0.981023  6.593492  0.171251  3.845988
# 4 -2.963069  2.739562  1.580715  ...  0.808296  5.361189  4.092647  4.238031
#
#         f18       f19  Subject_Id  \
# ...

# %%
Intracerebral.head()
# Out:
#          f0        f1        f2        f3        f4        f5        f6  \
# 0 -0.383299  1.689588  3.149935 -2.924374 -5.394772 -2.890231  0.684692
# 1  0.401371  0.939211  1.068421 -0.234447  0.106478 -0.879339 -0.100118
# 2  0.183651  1.181543 -0.293134  0.687296 -2.007638 -1.858179 -1.715379
# 3  0.589201  3.292905  5.589737 -0.581722 -1.742390 -2.891679  1.481472
# 4  2.110524  2.803512  1.970455 -0.252755 -0.728380 -2.364975 -1.440618
#
#          f7        f8        f9  ...       f14       f15       f16       f17  \
# 0 -1.067920 -5.294878  1.124837  ...  1.159260  0.412675 -1.125124 -2.567962
# 1  0.554368 -0.533087  0.101150  ... -0.441363  0.799222  0.225583  0.513968
# 2 -1.613486 -3.773669  0.358519  ... -1.348659  0.367709  0.895867  1.753837
# 3 -1.088630 -0.451929  1.034513  ... -5.376029  2.082192  4.042600  0.891869
# 4 -1.009266  0.135583 -0.657284  ...  1.477260  0.775054  1.229229  0.176332
#
#         f18       f19  Subject_Id  \
# ...

# %% [markdown]
# # Merge Data sets

# %%
frames = [Subarachnoid,Intracerebral]
repository_df = pd.concat(frames)
repository_df=repository_df.reset_index(drop=False)
repository_df.shape
# Out:
# (1072, 25)

# %%
#repository_df=Malignant

# %%
from sklearn.utils import shuffle
repository_df = shuffle(repository_df)
repository_df
# Out:
#      index        f0        f1        f2        f3        f4        f5  \
# 385    385  0.967421 -1.941539 -3.859261 -5.530046 -8.244544  1.139873
# 150    150 -0.943767 -1.288403  1.108463 -0.882988 -0.153136 -0.639859
# 974    538  0.052618  0.157267  1.124466 -0.387588 -0.484625 -0.653380
# 487     51  2.353692 -2.174082  4.537708 -1.673468 -2.514239 -4.495135
# 550    114  0.680011 -0.210753  1.159835 -0.074068 -0.877332 -1.308017
# ..     ...       ...       ...       ...       ...       ...       ...
# 982    546  4.135492  4.613986  3.141129 -0.955749  1.299894 -0.239065
# 564    128 -0.348050  2.675783  0.058118 -0.134315 -0.886483  0.594129
# 10      10 -1.149696 -2.042089  1.717715 -0.410449 -2.690749  4.087576
# 566    130 -2.256500  1.728569  7.095601  0.987684 -3.282745  1.656830
# 519     83  0.036685  0.159079  0.696061 -0.256195 -0.241029 -0.352053
#
#            f6        f7        f8  ...       f14       f15       f16  \
# ...

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

# %%
labels = repository_df['Target']
features =  repository_df.iloc[:, 1:21]
features
# Out:
#            f0        f1        f2        f3        f4        f5        f6  \
# 385  0.967421 -1.941539 -3.859261 -5.530046 -8.244544  1.139873 -9.740093
# 150 -0.943767 -1.288403  1.108463 -0.882988 -0.153136 -0.639859 -1.090575
# 974  0.052618  0.157267  1.124466 -0.387588 -0.484625 -0.653380  0.076964
# 487  2.353692 -2.174082  4.537708 -1.673468 -2.514239 -4.495135 -0.623211
# 550  0.680011 -0.210753  1.159835 -0.074068 -0.877332 -1.308017  0.042414
# ..        ...       ...       ...       ...       ...       ...       ...
# 982  4.135492  4.613986  3.141129 -0.955749  1.299894 -0.239065  0.246438
# 564 -0.348050  2.675783  0.058118 -0.134315 -0.886483  0.594129  0.195149
# 10  -1.149696 -2.042089  1.717715 -0.410449 -2.690749  4.087576 -2.549558
# 566 -2.256500  1.728569  7.095601  0.987684 -3.282745  1.656830  0.998295
# 519  0.036685  0.159079  0.696061 -0.256195 -0.241029 -0.352053 -0.003571
#
#            f7        f8        f9       f10       f11       f12       f13  \
# ...

# %%
print(labels.shape)
print(features.shape)
# Out:
# (1072,)
# (1072, 20)

# %% [markdown]
# # train_test_split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size = 0.2)

# %% [markdown]
# # SVM - Binary

# %%
from sklearn.svm import SVC
svclassifier = SVC(kernel='linear')
svclassifier.fit(X_train, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
y_pred = svclassifier.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[ 71  18]
#  [ 21 105]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.80      0.78        89
#            1       0.85      0.83      0.84       126
#
#     accuracy                           0.82       215
#    macro avg       0.81      0.82      0.81       215
# weighted avg       0.82      0.82      0.82       215
