# %%
import pandas as pd

# %% [markdown]
# ## Load Drug Stage

# %%
Stage_df_Drug=pd.read_csv("D:\Embedding\Code\Data\Processrd_Data\Stage_Drug_Malignant.csv")
Stage_df_Drug
# Out:
#        Subject_id  Subgraph_id  admission_Id  ago Timestame_id Event type  \
# 0             528            1        115758    0   2181-04-24       Drug
# 1             528            1        115758    0   2181-04-25       Drug
# 2             528            1        115758    0   2181-04-24       Drug
# 3             528            1        115758    0   2181-04-25       Drug
# 4             528            1        115758    0   2181-04-26       Drug
# ...           ...          ...           ...  ...          ...        ...
# 16405       63621            1        124508    0   2134-07-02       Drug
# 16406       63621            1        124508    0   2134-06-30       Drug
# 16407       63621            1        124508    0   2134-07-01       Drug
# 16408       63621            1        124508    0   2134-07-02       Drug
# 16409       63621            1        124508    0   2134-07-02       Drug
#
#       entity                     value
# 0       Main        Hydromorphone P.F.
# ...

# %% [markdown]
# ## Load Note Stage

# %%
Stage_df_Note=pd.read_csv("D:\Embedding\Code\Data\Processrd_Data\Stage_Note_Malignant.csv")
Stage_df_Note
# Out:
#      index  Subject_id  Subgraph_id  admission_Id   ago Timestame_id  \
# 0       58          20            1        157681    20   2183-04-28
# 1       60          20            1        157681    20   2183-04-28
# 2       62          20            1        157681    20   2183-04-28
# 3       63          20            1        157681    20   2183-04-28
# 4       64          20            1        157681    20   2183-04-28
# ..     ...         ...          ...           ...   ...          ...
# 651    126        1991            1        111425  1991   2194-08-08
# 652    127        1991            1        111425  1991   2194-08-08
# 653    128        1991            1        111425  1991   2194-08-08
# 654    129        1991            1        111425  1991   2194-08-08
# 655    133        1991            1        111425  1991   2194-08-08
#
#         Event type                  entity  \
# 0    Nursing/other  DiseaseDisorderMention
# 1    Nursing/other  DiseaseDisorderMention
# ...

# %% [markdown]
# # Merge Stage

# %%
frames = [Stage_df_Drug,Stage_df_Note]
Stage_Total = pd.concat(frames)
Stage_Total=Stage_Total.reset_index(drop=False)

# %% [markdown]
# # Save Stage Total

# %%
Stage_Total.to_csv('D:\Embedding\Code\Data\Processrd_Data\Stage_Total_Malignant.csv', index = False)

# %%
Stage_Total.shape
# Out:
# (17066, 10)
